# %%
import pandas as pd
import seaborn as sb

# %% [markdown]
# # 2017 data

# %%
data_2017 = pd.read_csv("data_2017.csv")

# %%
data_2017.head()
# Out:
#    RegisterNo  Year Semester        Depart PaperCode  \
# 0          38  2017       S1  BA.Economics  EN1CCT01
# 1          38  2017       S1  BA.Economics  EN1CCT02
# 2          38  2017       S1  BA.Economics  HN1CCT01
# 3          38  2017       S1  BA.Economics  EC1CRT01
# 4          38  2017       S1  BA.Economics  HY1CMT02
#
#                                        Paper  PaperCredit  ExternalMark  \
# 0         English - Fine - tune Your English            4            33
# 1               English-Pearls from the Deep            3            32
# 2              Hindi-Prose and One Act Plays            4            29
# 3  Perspectives and Methodology of Economics            4            43
# 4      Social Formations in Pre Modern India            4            29
#
#    ExternalMarkMax  InternalMark  ...  Grade  GradePoint  CreditScore  \
# 0               80            14  ...      C           5           20
# ...

# %%
data_2017.shape
print("Number of rows: ",data_2017.shape[0])
print("Number of columns: ",data_2017.shape[1])
# Out:
# Number of rows:  2480
# Number of columns:  23

# %%
data_2017.isnull().sum() # there is no missing value in this dataset of 2017
# Out:
# RegisterNo         0
# Year               0
# Semester           0
# Depart             0
# PaperCode          0
# Paper              0
# PaperCredit        0
# ExternalMark       0
# ExternalMarkMax    0
# InternalMark       0
# InternalMarkMax    0
# TotalMark          0
# TotalMarkMax       0
# Grade              0
# GradePoint         0
# CreditScore        0
# FinalResult        0
# ProgramCode        0
# Program            0
# Course             0
# Coursecode         0
# Mode               0
# Type               0
# dtype: int64

# %% [markdown]
# # data 2018

# %%
data_2018 =pd.read_csv("data_2018.csv")

# %%
data_2018.head()
# Out:
#    RegisterNo  Year Semester        Depart PaperCode  \
# 0          58  2018       S1  BA.Economics  EN1CCT01
# 1          58  2018       S1  BA.Economics  EN1CCT02
# 2          58  2018       S1  BA.Economics  FR1CCT01
# 3          58  2018       S1  BA.Economics  EC1CRT01
# 4          58  2018       S1  BA.Economics  HY1CMT02
#
#                                                Paper  PaperCredit  \
# 0                 English - Fine - tune Your English            4
# 1                       English-Pearls from the Deep            3
# 2  French -French Language & Communicative Skills...            4
# 3          Perspectives and Methodology of Economics            4
# 4              Social Formations in Pre Modern India            4
#
#    ExternalMark  ExternalMarkMax  InternalMark  ...  Grade  GradePoint  \
# 0            52               80            18  ...     B+           7
# 1            44               80            19  ...      B           6
# ...

# %%
data_2018.shape
print("Number of rows: ",data_2017.shape[0])
print("Number of columns: ",data_2017.shape[1])
# Out:
# Number of rows:  2480
# Number of columns:  23

# %%
data_2018.isnull().sum() # there is no missing value in this dataset of 2018
# Out:
# RegisterNo         0
# Year               0
# Semester           0
# Depart             0
# PaperCode          0
# Paper              0
# PaperCredit        0
# ExternalMark       0
# ExternalMarkMax    0
# InternalMark       0
# InternalMarkMax    0
# TotalMark          0
# TotalMarkMax       0
# Grade              0
# GradePoint         0
# CreditScore        0
# FinalResult        0
# ProgramCode        0
# Program            0
# Course             0
# Coursecode         0
# Mode               0
# Type               0
# dtype: int64

# %% [markdown]
# # Comparision start from here between 2017 & 2018 data

# %% [markdown]
# # No. of Rows & Column

# %%
data_2017.shape
# Out:
# (2480, 23)

# %%
data_2018.shape
# Out:
# (2383, 23)

# %% [markdown]
# # Information about the dataset

# %%
data_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RegisterNo       2480 non-null   int64
#  1   Year             2480 non-null   int64
#  2   Semester         2480 non-null   object
#  3   Depart           2480 non-null   object
#  4   PaperCode        2480 non-null   object
#  5   Paper            2480 non-null   object
#  6   PaperCredit      2480 non-null   int64
#  7   ExternalMark     2480 non-null   int64
#  8   ExternalMarkMax  2480 non-null   int64
#  9   InternalMark     2480 non-null   int64
#  10  InternalMarkMax  2480 non-null   int64
#  11  TotalMark        2480 non-null   int64
#  12  TotalMarkMax     2480 non-null   int64
#  13  Grade            2480 non-null   object
#  14  GradePoint       2480 non-null   int64
#  15  CreditScore      2480 non-null   int64
#  16  FinalResult      2480 non-null   object
# ...

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2383 entries, 0 to 2382
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RegisterNo       2383 non-null   int64
#  1   Year             2383 non-null   int64
#  2   Semester         2383 non-null   object
#  3   Depart           2383 non-null   object
#  4   PaperCode        2383 non-null   object
#  5   Paper            2383 non-null   object
#  6   PaperCredit      2383 non-null   int64
#  7   ExternalMark     2383 non-null   int64
#  8   ExternalMarkMax  2383 non-null   int64
#  9   InternalMark     2383 non-null   int64
#  10  InternalMarkMax  2383 non-null   int64
#  11  TotalMark        2383 non-null   int64
#  12  TotalMarkMax     2383 non-null   int64
#  13  Grade            2383 non-null   object
#  14  GradePoint       2383 non-null   int64
#  15  CreditScore      2383 non-null   int64
#  16  FinalResult      2383 non-null   object
# ...

# %% [markdown]
# # Department infomation

# %%
data_2017["Depart"].unique()
# Out:
# array(['BA.Economics', 'BA.History', 'BA.Sociology', 'Bsc.Botany',
#        'Bsc.Chemistry', 'BSc.FACS ', 'BSc.Maths', 'BSc.Physics',
#        'BSc.Zoology', 'BSc.Computer Science'], dtype=object)

# %%
data_2018["Depart"].unique()
# Out:
# array(['BA.Economics', 'BA.History', 'BA.Sociology', 'Bsc.Botany',
#        'Bsc.Chemistry', 'BSc.FACS ', 'BSc.Maths', 'BSc.Physics',
#        'BSc.Zoology', 'BSc.Computer Science'], dtype=object)

# %% [markdown]
# # mean, max & min of ExternalMark

# %%
data_2017["ExternalMark"].max()
# Out:
# 80

# %%
data_2018["ExternalMark"].max()
# Out:
# 80

# %%
data_2017["ExternalMark"].min()
# Out:
# 13

# %%
data_2018["ExternalMark"].min()
# Out:
# 13

# %% [markdown]
# # Only there is a difference in the average

# %%
data_2017["ExternalMark"].mean()
# Out:
# 45.80564516129032

# %%
data_2018["ExternalMark"].mean()
# Out:
# 45.51867394041125

# %% [markdown]
# # visualization based on ExternalMark

# %%
sb.violinplot('ExternalMark','Semester',data=data_2017,orientation='v')
# Out:
# <AxesSubplot:xlabel='ExternalMark', ylabel='Semester'>

# %%
sb.countplot("ExternalMark",hue="Semester",data=data_2017)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExternalMark', ylabel='count'>

# %%
sb.countplot("ExternalMark",hue="Semester",data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExternalMark', ylabel='count'>

# %% [markdown]
# # visualization based on ExternalMarkMax

# %%
sb.countplot("ExternalMarkMax",hue="Semester",data=data_2017)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExternalMarkMax', ylabel='count'>

# %%
sb.countplot("ExternalMarkMax",hue="Semester",data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ExternalMarkMax', ylabel='count'>

# %% [markdown]
# # By this plot , we can make out that there is a progress in 2017 compare to 2018 in External Maximum mark

# %% [markdown]
# #

# %%
sb.countplot("InternalMark",hue="Semester",data=data_2017)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternalMark', ylabel='count'>

# %%
sb.countplot("InternalMark",hue="Semester",data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternalMark', ylabel='count'>

# %% [markdown]
# # There is a minor difference in Internal mark between both

# %%
sb.boxplot('InternalMark','Semester',data=data_2017)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternalMark', ylabel='Semester'>

# %%
sb.boxplot('InternalMark','Semester',data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternalMark', ylabel='Semester'>

# %%
sb.countplot("InternalMarkMax",hue="Semester",data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='InternalMarkMax', ylabel='count'>

# %% [markdown]
# # Total Mark

# %%
sb.countplot("TotalMark",hue="Depart",data=data_2017)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalMark', ylabel='count'>

# %%
sb.countplot("TotalMark",hue="Depart",data=data_2018)
# Out:
# C:\Users\91986\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='TotalMark', ylabel='count'>

# %%
sb.scatterplot(x= "FinalResult",  data=data_2017,hue="Depart")
# Out:
# <AxesSubplot:xlabel='FinalResult'>

# %%
sb.scatterplot(x= "FinalResult",  data=data_2018,hue="Depart")
# Out:
# <AxesSubplot:xlabel='FinalResult'>

# %% [markdown]
# # Based Grade

# %%
data_2017["Grade"].mode()
# Out:
# 0    A
# Name: Grade, dtype: object

# %%
data_2018["Grade"].mode()
# Out:
# 0    B+
# Name: Grade, dtype: object

# %%
sb.displot(data_2017['Grade'])

# %%
sb.displot(data_2018['Grade'])

# %% [markdown]
# # With the help of graph we can make out that 2017 has better performance than 2018
